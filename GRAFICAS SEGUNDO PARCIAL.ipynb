# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x_0 = 0 # inicia el caminador
elements = [1, -1] # Aguila o Sol
probabilites = [0.5, 0.5] # P(Aguila) = 0.5 P(Sol) = 0.5
delta_x = np.random.choice(elements, 10, p=probabilites)

y = np.ones(len(np.cumsum(delta_x)))
#plt.plot(np.cumsum(delta_x),y)
plt.plot(np.cumsum(delta_x))
plt.xlabel('Tiempo')
plt.ylabel('Distancia')

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion == 0:
        x+=1
    elif eleccion ==1:
        x-=1
    elif eleccion ==2:
        y+=1
    else:
        y-=1
    return[x,y]

x = 0 #inicia el caminador
y = 0

Pos = np.zeros((2,10))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')

# %%
random.uniform(-1,1)
# Out:
# -0.6306159509269467

# %%
def walker():
    global x,y
    x += random.randint(-1,1)
    y += random.randint(-1,1)
    return[x,y]

x = 0 #inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')

# %%
x_0 = np.array([[0],[0]])
delta_x = np.random.uniform(-1,1,(2,100))

x = np.concatenate( (x_0,np.cumsum(delta_x,axis=1)),axis=1)
rw = plt.plot(x[0],x[1],'ro-')

# %%
plt.hist(np.random.normal(0,1,(1000))
# Out:
#   File "<ipython-input-36-e3c141019051>", line 1
#     plt.hist(np.random.normal(0,1,(1000))
#                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
x_0 = np.array([[0],[0]])
delta_x = np.random.uniform(-1,1,(2,100))

x = np.concatenate( (x_0,np.cumsum(delta_x,axis=1)),axis=1)
rw = plt.plot(x[0],x[1],'ro-')

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion < 0.4:
        x+=1
    elif eleccion < 0.6:
        x-=1
    elif eleccion <0.8:
        y+=1
    else:
        y-=1
    return[x,y]

x = 0 #inicia el caminador
y = 0

Pos = np.zeros((2,10))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion < 0.1:
        x+=1
    elif eleccion < 0.2:
        x-=1
    elif eleccion <0.80:
        y+=1
    else:
        y-=1
    return[x,y]

x = 0 #inicia el caminador
y = 0

Pos = np.zeros((2,10))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    x += np.random.normal(0,2000)
    y += random.gauss(0,2000)
    return [x,y]

x = 0 #Inicia el caminador
y = 0

Pos = np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    r = random.uniform(0,1)
    if r< 0.01: #un 1% de probabilidad de tomar un paso grande
        x += np.random.normal(0,200)
        y += random.gauss(0,200)
    else:
        x += np.random.normal(0,1)
        y += random.gauss(0,1)
    return [x,y]


x = 0 #Inicia el caminador
y = 0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
    
plt.plot(Pos[0,:],Pos[1,:],'bo-')
plt.plot(Pos[0,-1],Pos[1,-1],'ro-')
